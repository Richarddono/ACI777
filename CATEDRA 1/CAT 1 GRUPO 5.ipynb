# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
PacienteM = pd.read_csv ("DATA/MASCULINO.csv")
PacienteF = pd.read_csv ("DATA/FEMENINO.csv")

# %%
PM = pd.DataFrame(PacienteM)
PF = pd.DataFrame(PacienteF)

# %%
Masculino = PM.rename({'0':'Tiempo en segundos', '0.30721':'Lectura de aceleración en G para eje frontal', 
                       '0.89339': 'Lectura de aceleración en G para eje vertical', 
                       '0.020525' : 'Lectura de aceleración en G para eje lateral',
                       '2' : 'Id del sensor de lectura de la antena', 
                       '-56.5' :'Intensidad de la señal recibida indicador (RSSI)', 
                       '5.5745':'Fase', '923.25':'Frecuencia',
       '4':'Etiqueta de actividad= 1. sentarse en la cama 2. sentarse en una silla 3. acostado 4. deambular'}, axis=1)

# %%
Masculino
# Out:
#      Tiempo en segundos  Lectura de aceleración en G para eje frontal  \
# 0                 3.000                                      0.307210
# 1                 3.025                                      0.307210
# 2                 5.250                                      0.318930
# 3                 5.750                                      0.318930
# 4                 6.500                                      0.318930
# ..                  ...                                           ...
# 233             371.500                                      0.975550
# 234             372.000                                      1.139700
# 235             372.100                                      1.139700
# 236             373.250                                      0.694140
# 237             374.750                                     -0.021106
#
#      Lectura de aceleración en G para eje vertical  \
# 0                                          0.89339
# ...

# %%
Masculino
# Out:
#      Tiempo en segundos  Lectura de aceleración en G para eje frontal  \
# 0                 3.000                                      0.307210
# 1                 3.025                                      0.307210
# 2                 5.250                                      0.318930
# 3                 5.750                                      0.318930
# 4                 6.500                                      0.318930
# ..                  ...                                           ...
# 233             371.500                                      0.975550
# 234             372.000                                      1.139700
# 235             372.100                                      1.139700
# 236             373.250                                      0.694140
# 237             374.750                                     -0.021106
#
#      Lectura de aceleración en G para eje vertical  \
# 0                                          0.89339
# ...

# %%
Femenino= PF.rename({'0': 'Tiempo en segundos', '0.51826': 'Lectura de aceleración en G para eje frontal', '0.89339': 'Lectura de aceleración en G para eje vertical', '0.13456': 'Lectura de aceleración en G para eje lateral','4': 'Id del sensor de lectura de la antena', '-56.5':'Intensidad de la señal recibida indicador (RSSI)', '5.8368':'Fase', '921.75': 'Frecuencia', '1':'Etiqueta de actividad, 1: sentarse en la cama, 2: sentarse en una silla, 3: acostado, 4: deambular' }, axis=1)

# %%
Femenino
# Out:
#     Tiempo en segundos  Lectura de aceleración en G para eje frontal  \
# 0                 0.25                                       0.51826
# 1                 0.75                                       0.51826
# 2                 1.25                                       0.51826
# 3                 1.75                                       0.51826
# 4               141.25                                       0.43619
# ..                 ...                                           ...
# 86              268.75                                       0.44791
# 87              273.75                                       0.44791
# 88              294.53                                       0.45964
# 89              318.50                                       0.58862
# 90              328.50                                       0.48309
#
#     Lectura de aceleración en G para eje vertical  \
# 0                                         0.89339
# ...

# %% [markdown]
# ## Media aritmetica (Promedio)

# %%
Masculino.mean(axis=0)
# Out:
# Tiempo en segundos                                                                                 193.790567
# Lectura de aceleración en G para eje frontal                                                         0.730996
# Lectura de aceleración en G para eje vertical                                                        0.456451
# Lectura de aceleración en G para eje lateral                                                         0.048650
# Id del sensor de lectura de la antena                                                                2.016807
# Intensidad de la señal recibida indicador (RSSI)                                                   -59.600840
# Fase                                                                                                 2.836104
# Frecuencia                                                                                         923.004202
# ...

# %%
Femenino.mean(axis=0)
# Out:
# Tiempo en segundos                                                                                    187.363956
# Lectura de aceleración en G para eje frontal                                                            0.605495
# Lectura de aceleración en G para eje vertical                                                           0.767832
# Lectura de aceleración en G para eje lateral                                                            0.244577
# Id del sensor de lectura de la antena                                                                   2.252747
# Intensidad de la señal recibida indicador (RSSI)                                                      -58.368132
# Fase                                                                                                    3.325877
# Frecuencia                                                                                            923.447802
# ...

# %% [markdown]
# ## Desviacion Estandar

# %%
Masculino.std(axis=0)
# Out:
# Tiempo en segundos                                                                                 112.887132
# Lectura de aceleración en G para eje frontal                                                         0.348326
# Lectura de aceleración en G para eje vertical                                                        0.546014
# Lectura de aceleración en G para eje lateral                                                         0.103982
# Id del sensor de lectura de la antena                                                                1.035107
# Intensidad de la señal recibida indicador (RSSI)                                                     5.315204
# Fase                                                                                                 2.197612
# Frecuencia                                                                                           1.507885
# ...

# %%
Femenino.std(axis=0)
# Out:
# Tiempo en segundos                                                                                    55.834825
# Lectura de aceleración en G para eje frontal                                                           0.103706
# Lectura de aceleración en G para eje vertical                                                          0.295355
# Lectura de aceleración en G para eje lateral                                                           0.223513
# Id del sensor de lectura de la antena                                                                  0.810945
# Intensidad de la señal recibida indicador (RSSI)                                                       3.120573
# Fase                                                                                                   1.973523
# Frecuencia                                                                                             1.625968
# ...

# %% [markdown]
# ### Varianza

# %%
Masculino.var(axis=0)
# Out:
# Tiempo en segundos                                                                                 12743.504558
# Lectura de aceleración en G para eje frontal                                                           0.121331
# Lectura de aceleración en G para eje vertical                                                          0.298132
# Lectura de aceleración en G para eje lateral                                                           0.010812
# Id del sensor de lectura de la antena                                                                  1.071446
# Intensidad de la señal recibida indicador (RSSI)                                                      28.251392
# Fase                                                                                                   4.829501
# Frecuencia                                                                                             2.273716
# ...

# %%
Femenino.var(axis=0)
# Out:
# Tiempo en segundos                                                                                    3117.527660
# Lectura de aceleración en G para eje frontal                                                             0.010755
# Lectura de aceleración en G para eje vertical                                                            0.087235
# Lectura de aceleración en G para eje lateral                                                             0.049958
# Id del sensor de lectura de la antena                                                                    0.657631
# Intensidad de la señal recibida indicador (RSSI)                                                         9.737973
# Fase                                                                                                     3.894792
# Frecuencia                                                                                               2.643773
# ...

# %% [markdown]
# ### Mediana

# %%
Masculino.median(axis=0)
# Out:
# Tiempo en segundos                                                                                 212.675000
# Lectura de aceleración en G para eje frontal                                                         0.682420
# Lectura de aceleración en G para eje vertical                                                        0.824490
# Lectura de aceleración en G para eje lateral                                                         0.066138
# Id del sensor de lectura de la antena                                                                2.000000
# Intensidad de la señal recibida indicador (RSSI)                                                   -58.500000
# Fase                                                                                                 1.773250
# Frecuencia                                                                                         923.250000
# ...

# %%
Femenino.median(axis=0)
# Out:
# Tiempo en segundos                                                                                    190.25000
# Lectura de aceleración en G para eje frontal                                                            0.61207
# Lectura de aceleración en G para eje vertical                                                           0.84746
# Lectura de aceleración en G para eje lateral                                                            0.19157
# Id del sensor de lectura de la antena                                                                   2.00000
# Intensidad de la señal recibida indicador (RSSI)                                                      -57.50000
# Fase                                                                                                    4.22460
# Frecuencia                                                                                            923.25000
# ...

# %% [markdown]
# ### Moda

# %%
Masculino.mode()
# Out:
#      Tiempo en segundos  Lectura de aceleración en G para eje frontal  \
# 0                 3.000                                       0.55344
# 1                 3.025                                           NaN
# 2                 5.250                                           NaN
# 3                 5.750                                           NaN
# 4                 6.500                                           NaN
# ..                  ...                                           ...
# 233             371.500                                           NaN
# 234             372.000                                           NaN
# 235             372.100                                           NaN
# 236             373.250                                           NaN
# 237             374.750                                           NaN
#
#      Lectura de aceleración en G para eje vertical  \
# 0                                          0.82449
# ...

# %%
Femenino.mode()
# Out:
#     Tiempo en segundos  Lectura de aceleración en G para eje frontal  \
# 0                 0.25                                       0.62379
# 1                 0.75                                           NaN
# 2                 1.25                                           NaN
# 3                 1.75                                           NaN
# 4               141.25                                           NaN
# ..                 ...                                           ...
# 86              268.75                                           NaN
# 87              273.75                                           NaN
# 88              294.53                                           NaN
# 89              318.50                                           NaN
# 90              328.50                                           NaN
#
#     Lectura de aceleración en G para eje vertical  \
# 0                                         0.84746
# ...

# %% [markdown]
# ### Percentil

# %%
Masculino.quantile(0.)
# Out:
# Tiempo en segundos                                                                                  89.625000
# Lectura de aceleración en G para eje frontal                                                         0.477222
# Lectura de aceleración en G para eje vertical                                                       -0.174540
# Lectura de aceleración en G para eje lateral                                                        -0.033639
# Id del sensor de lectura de la antena                                                                1.000000
# Intensidad de la señal recibida indicador (RSSI)                                                   -64.500000
# Fase                                                                                                 0.852897
# Frecuencia                                                                                         921.750000
# ...

# %%
Femenino.quantile(0.25)
# Out:
# Tiempo en segundos                                                                                    161.50000
# Lectura de aceleración en G para eje frontal                                                            0.57689
# Lectura de aceleración en G para eje vertical                                                           0.80152
# Lectura de aceleración en G para eje lateral                                                            0.14026
# Id del sensor de lectura de la antena                                                                   2.00000
# Intensidad de la señal recibida indicador (RSSI)                                                      -58.50000
# Fase                                                                                                    1.05000
# Frecuencia                                                                                            922.25000
# ...

# %% [markdown]
# ### Cuartil

# %%
print (Masculino.quantile(0.25), 
       Masculino.quantile(0.50) , 
       Masculino.quantile(0.75))
# Out:
# Tiempo en segundos                                                                                  89.625000
# Lectura de aceleración en G para eje frontal                                                         0.477222
# Lectura de aceleración en G para eje vertical                                                       -0.174540
# Lectura de aceleración en G para eje lateral                                                        -0.033639
# Id del sensor de lectura de la antena                                                                1.000000
# Intensidad de la señal recibida indicador (RSSI)                                                   -64.500000
# Fase                                                                                                 0.852897
# Frecuencia                                                                                         921.750000
# ...

# %%
print (Femenino.quantile(0.25) ,
       Femenino.quantile(0.50) ,
       Femenino.quantile(0.75))
# Out:
# Tiempo en segundos                                                                                    161.50000
# Lectura de aceleración en G para eje frontal                                                            0.57689
# Lectura de aceleración en G para eje vertical                                                           0.80152
# Lectura de aceleración en G para eje lateral                                                            0.14026
# Id del sensor de lectura de la antena                                                                   2.00000
# Intensidad de la señal recibida indicador (RSSI)                                                      -58.50000
# Fase                                                                                                    1.05000
# Frecuencia                                                                                            922.25000
# ...

# %% [markdown]
# ### Rango

# %%
Masculino.rank()
# Out:
#      Tiempo en segundos  Lectura de aceleración en G para eje frontal  \
# 0                   1.0                                          28.5
# 1                   2.0                                          28.5
# 2                   3.0                                          32.5
# 3                   4.0                                          32.5
# 4                   5.0                                          32.5
# ..                  ...                                           ...
# 233               234.0                                         165.5
# 234               235.0                                         207.0
# 235               236.0                                         207.0
# 236               237.0                                         123.0
# 237               238.0                                           4.0
#
#      Lectura de aceleración en G para eje vertical  \
# 0                                            176.0
# ...
