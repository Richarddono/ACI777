# %% [markdown]
# Richard Donoso Saavedra       /10/2021
#
# 1. Crear una carpeta nueva en su repositorio git con el nombre E2 (0.2 pto)
# 2. Dentro de E2 crear una carpeta que se llame data. (0.2 pto)
# 3. Guardar los datos asignados en esa carpeta. (0.2 pto)
# 4. Dentro de E2 debera crear un Jupyter Notebook llamado E2. (0.2 pto)
# 5. En el Jupyter Notebook, configurar la primera casilla en Lenguaje Markdown y escribir su nombre, fecha, y esta lista de instrucciones de forma ordenada. (0.2 pts)
# 6. Importar la librería pandas de python para poder procesar y graficar los datos del archivo. Utilizar describe, shape e indicar para que se utilizan estos comandos y que puede deducir de esta información. Debe separar el código en las casillas que estime conveniente, pero se solicita minimo que en una casilla esten solo las importaciones, en otra solo la lectura de los datos y otra con los plots, además cada casilla debe tener una casilla previa que describa el código en formato markdown. (3 pts)
# 7. Hacer los gráficos correspondientes al conjunto de datos seleccionado. (1 pts)
# 8. Utilizar los comandos adecuados de git para actualizar su repositorio y dejarlo disponible en github de forma pública. (1 pts)
#
#
# Deberas hacer el:
# 1. gráfico de los casos en el tiempo por rango etario.
# 2. gráfico de los casos acumulados en el tiempo totales

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
F=pd.read_csv('Data/FallecidosEtario.csv', index_col=0)

# %%
F
# Out:
#                2020-04-09  2020-04-10  2020-04-11  2020-04-12  2020-04-13  \
# Grupo de edad
# <=39                    2           2           3           3           3
# 40-49                   1           2           2           2           2
# 50-59                   1           2           2           3           3
# 60-69                   9          10          12          12          12
# 70-79                  21          22          24          28          29
# 80-89                  19          21          24          25          26
# >=90                    4           6           6           7           7
#
#                2020-04-14  2020-04-15  2020-04-16  2020-04-17  2020-04-18  \
# Grupo de edad
# <=39                    3           3           3           4           4
# 40-49                   2           2           2           2           2
# 50-59                   5           5           6           8           8
# 60-69                  12          12          14          16          17
# 70-79                  30          31          32          36          39
# 80-89                  32          33          38          40          44
# >=90                    8           8          10          10          12
#
#                ...  2021-09-17  2021-09-18  2021-09-19  2021-09-20  \
# Grupo de edad  ...
# <=39           ...        1047        1048        1049        1049
# 40-49          ...        1581        1582        1583        1584
# 50-59          ...        4129        4132        4135        4135
# 60-69          ...        7624        7629        7635        7636
# 70-79          ...       10166       10173       10179       10183
# 80-89          ...        9195        9198        9200        9201
# >=90           ...        3576        3577        3578        3579
#
#                2021-09-21  2021-09-22  2021-09-23  2021-09-24  2021-09-25  \
# Grupo de edad
# <=39                 1050        1050        1050        1050        1050
# 40-49                1584        1584        1584        1584        1585
# 50-59                4135        4136        4137        4140        4141
# 60-69                7639        7640        7648        7648        7652
# 70-79               10184       10187       10195       10204       10206
# 80-89                9202        9202        9215        9216        9217
# >=90                 3580        3580        3581        3581        3581
#
#                2021-09-26
# Grupo de edad
# <=39                 1050
# 40-49                1585
# 50-59                4141
# 60-69                7654
# 70-79               10211
# 80-89                9218
# >=90                 3581
#
# [7 rows x 536 columns]

# %% [markdown]
# ###### El Describe funciona para describir el data frame y nos entrega un contador, media aritmetica, desviacion estandar, el valor mas bajo y el alto y percentiles 25, 50 y 70.

# %%
F.describe()
# Out:
#        2020-04-09  2020-04-10  2020-04-11  2020-04-12  2020-04-13  2020-04-14  \
# count    7.000000    7.000000    7.000000    7.000000    7.000000    7.000000
# mean     8.142857    9.285714   10.428571   11.428571   11.714286   13.142857
# std      8.571825    8.845230    9.897090   10.875924   11.338934   12.654756
# min      1.000000    2.000000    2.000000    2.000000    2.000000    2.000000
# 25%      1.500000    2.000000    2.500000    3.000000    3.000000    4.000000
# 50%      4.000000    6.000000    6.000000    7.000000    7.000000    8.000000
# 75%     14.000000   15.500000   18.000000   18.500000   19.000000   21.000000
# max     21.000000   22.000000   24.000000   28.000000   29.000000   32.000000
#
#        2020-04-15  2020-04-16  2020-04-17  2020-04-18  ...    2021-09-17  \
# count    7.000000    7.000000    7.000000    7.000000  ...      7.000000
# mean    13.428571   15.000000   16.571429   18.000000  ...   5331.142857
# std     13.125765   14.364308   15.349888   16.862186  ...   3663.003205
# min      2.000000    2.000000    2.000000    2.000000  ...   1047.000000
# 25%      4.000000    4.500000    6.000000    6.000000  ...   2578.500000
# 50%      8.000000   10.000000   10.000000   12.000000  ...   4129.000000
# 75%     21.500000   23.000000   26.000000   28.000000  ...   8409.500000
# max     33.000000   38.000000   40.000000   44.000000  ...  10166.000000
#
#          2021-09-18    2021-09-19    2021-09-20    2021-09-21    2021-09-22  \
# count      7.000000      7.000000      7.000000      7.000000      7.000000
# mean    5334.142857   5337.000000   5338.142857   5339.142857   5339.857143
# std     3664.982830   3666.671561   3667.581511   3668.015741   3668.726047
# min     1048.000000   1049.000000   1049.000000   1050.000000   1050.000000
# 25%     2579.500000   2580.500000   2581.500000   2582.000000   2582.000000
# 50%     4132.000000   4135.000000   4135.000000   4135.000000   4136.000000
# 75%     8413.500000   8417.500000   8418.500000   8420.500000   8421.000000
# max    10173.000000  10179.000000  10183.000000  10184.000000  10187.000000
#
#          2021-09-23    2021-09-24    2021-09-25    2021-09-26
# count      7.000000      7.000000      7.000000      7.000000
# mean    5344.285714   5346.142857   5347.428571   5348.571429
# std     3673.470462   3675.463437   3676.271882   3677.757780
# min     1050.000000   1050.000000   1050.000000   1050.000000
# 25%     2582.500000   2582.500000   2583.000000   2583.000000
# 50%     4137.000000   4140.000000   4141.000000   4141.000000
# 75%     8431.500000   8432.000000   8434.500000   8436.000000
# max    10195.000000  10204.000000  10206.000000  10211.000000
#
# [8 rows x 536 columns]

# %% [markdown]
# ###### El shape sirve para saber las filas y columnas que hay.

# %%
F.shape
# Out:
# (7, 536)

# %%
ejeX=np.arange(len(F.columns),step=7)
xlabels=list (F.columns)

# %% [markdown]
# ###  1. gráfico de los casos en el tiempo por rango etario.

# %%
F.T.plot(figsize=(50,15), xlabel="FECHAS POR SEMANA", ylabel="CASOS" , 
         title = "GRAFICO DE LOS CASOS EN EL TIEMPO POR RANGO ETARIO", xticks=ejeX, rot=90)
# Out:
# <AxesSubplot:title={'center':'GRAFICO DE LOS CASOS EN EL TIEMPO POR RANGO ETARIO'}, xlabel='FECHAS POR SEMANA', ylabel='CASOS'>

# %% [markdown]
# ### 2. gráfico de los casos acumulados en el tiempo totales

# %%
sumF = pd.DataFrame(F).sum()

# %%
sumF.plot(figsize=(50,15), xlabel="FECHAS POR SEMANA", ylabel="CASOS ACUMULADOS" , 
         title = "GRAFICO DE LOS CASOS ACUMULADOS EN EL TIEMPO TOTALES", xticks=ejeX, rot=90)
# Out:
# <AxesSubplot:title={'center':'GRAFICO DE LOS CASOS ACUMULADOS EN EL TIEMPO TOTALES'}, xlabel='FECHAS POR SEMANA', ylabel='CASOS ACUMULADOS'>

# %% [markdown]
# # Graficos con seaborn

# %% [markdown]
# ###  1. gráfico de los casos en el tiempo por rango etario.

# %%
plt.figure(figsize=(50,15))
sns.lineplot(data=F.T)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot?

# %%
# Out:
# Object `style_order` not found.
